# %% [markdown]
# <a href="https://colab.research.google.com/github/adrian5018251037/pemrograman-komputer-5018251037/blob/main/WO2_Engineering_Calculator_5018251037_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # week 2 assigment
# ## Engineering Unit and  Electrical Calculator
#
# Nama:Adrian Christoffel Matthew Sitorus
#
# NRP:5018251037
#
# kelas:Pemrograman komputer(A)

# %%
speed_kmh= float(input("Enter speed [km/h]:"))
speed_ms = speed_kmh / 3.6
print(f"speed = {speed_ms:.2f}m/s")
# Out:
# Enter speed [km/h]:20
# speed = 5.56m/s

# %%
power_kW = float(input("enter power [kW]:"))
power_W = 1000*power_kW
print(f"power = {power_W:.2f} W" )
# Out:
# enter power [kW]:15
# power = 15000.00 W

# %%
Voltage = float(input("enter voltage:"))
Current = float(input("enter current:"))
print(f"Voltage = {Voltage:.2f} V")
print(f"Current = {Current:.2f} A")
power = Voltage*current
print(f"power = {power:.2f} W")
Operating_Time = float(input("operating time:"))
print(f"Operating_Time = {Operating_Time:.2f} hour")
energy = power*Operating_Time
print(f"energy = {energy:.2f} Wh")
# Out:
# enter voltage:12
# enter current:5.0
# Voltage = 12.00 V
# Current = 5.00 A
# power = 24.00 W
# operating time:2.0
# Operating_Time = 2.00 hour
# energy = 48.00 Wh

# %%
Voltage = float(input("voltage:"))
Current = float(input("current:"))
print(f"Voltage = {Voltage:.2f} V")
print(f"Current = {Current:.2f} A")
power = Voltage*current
print(f"power = {power:.2f} W")
Operating_Time = float(input("operating time:"))
print(f"Operating_Time = {Operating_Time:.2f} hour")
energy = power*Operating_Time
print(f"energy = {energy:.2f} Wh")

power_limit = 200
Voltage_limit = 24

is_high_power = power > power_limit
is_high_voltage = Voltage > Voltage_limit

print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
# Out:
# voltage:24
# current:8.5
# Voltage = 24.00 V
# Current = 8.50 A
# power = 48.00 W
# operating time:3.0
# Operating_Time = 3.00 hour
# energy = 144.00 Wh
# High power : False
# High voltage : False
# Both conditions : False
# Any condition : False

# %%
Voltage = float(input("voltage:"))
Current = float(input("current:"))
print(f"Voltage = {Voltage:.2f} V")
print(f"Current = {Current:.2f} A")
power = Voltage*current
print(f"power = {power:.2f} W")
Operating_Time = float(input("operating time:"))
print(f"Operating_Time = {Operating_Time:.2f} hour")
energy = power*Operating_Time
print(f"energy = {energy:.2f} Wh")

power_limit = 200
Voltage_limit = 24

is_high_power = power > power_limit
is_high_voltage = Voltage > Voltage_limit

print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
# Out:
# voltage:24
# current:8.5
# Voltage = 24.00 V
# Current = 8.50 A
# power = 48.00 W
# operating time:3.0
# Operating_Time = 3.00 hour
# energy = 144.00 Wh
# High power : False
# High voltage : False
# Both conditions : False
# Any condition : False

# %%
Voltage = float(input("voltage:"))
Current = float(input("current:"))
print(f"Voltage = {Voltage:.2f} V")
print(f"Current = {Current:.2f} A")
power = Voltage*current
print(f"power = {power:.2f} W")
Operating_Time = float(input("operating time:"))
print(f"Operating_Time = {Operating_Time:.2f} hour")
energy = power*Operating_Time
print(f"energy = {energy:.2f} Wh")

power_limit = 200
Voltage_limit = 24

is_high_power = power > power_limit
is_high_voltage = Voltage > Voltage_limit

print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
# Out:
# voltage:48
# current:10.0
# Voltage = 48.00 V
# Current = 10.00 A
# power = 96.00 W
# operating time:1.5
# Operating_Time = 1.50 hour
# energy = 144.00 Wh
# High power : False
# High voltage : True
# Both conditions : False
# Any condition : True

# %% [markdown]
# 1.APA PERBEDAAN int dan Float?
#
# jawab:int untuk menyimpan bilangan bulat dan float untuk menyimpan bilangan desimal atau pecahan
#
# 2.Mengapa hasil input() perlu dikonversi menggunakan float() untuk perhitungan numerik?
#
# jawab:karena fungsi input() secara default membaca semua data dari pengguna sebagai teks atau tipe data string bukan angka
#
# 3.Apa perbedaan operator = dan == dalam Python?
#
# jawaban:= digunakan untuk memasukan nilai ke variabel sedangkan == untuk membandingkan apakah kedua nilai sama
#
# 4.Apa fungsi operator AND dan OR?
#
# jawab:Operator AND dan OR adalah operator logika yang digunakan untuk menggabungkan dua atau lebih kondisi atau pernyataan
#
# 5.Apa satu kesalahan yang Anda temui saat mengerjakan tugas ini, dan bagaimana Anda memperbaikinya?
#
# jawaban:satu kesalahan yang saya sering temui adalah seberapa akurat yang diperlukan untuk menginput kodingan, seperti salah satu yang saya sering hadapai adalah penggunaan huruf,jika huruf aja tidak sama bentuknya(huruf besar tanda baca dan lain lain) program otomatis salah
